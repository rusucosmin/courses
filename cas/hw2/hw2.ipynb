# %% [markdown]
# # Exercise 1 Order!

# %%
Q1_P_example = 84940741664701783868001830507508782986257930535317701830636617526195732939795174410659
Q1_order_ex = 751319
Q1_element_ex = 4225123973196700651016990525439265843464696652913211289917808426774665805285192409186811203664418086003535167251245193334877202815676254993053808887847165380229201330

Q1_P = 84781063191599258791351366609202062457287819352167174865024009269975345004536954879907

def ex1(Q1_P):
    F = Integers(Q1_P * Q1_P)
    
    O = Q1_P ^ 2 - 1
    O = (Q1_P - 1) // 2
    
    r = [d[0] for d in O.factor() if d[0] % 2 == 1][0]
    
    el = Mod(1, Q1_P * Q1_P).nth_root(r)
    sol = el
    x = 1
    for y in range(1,  r - 1):
        x = x * el
        if x < sol:
            sol = x
    assert(sol.multiplicative_order() == r)
    return (r, sol)

(r, el) = ex1(Q1_P_example)
print(r, el)
assert(r == Q1_order_ex)
assert(el == Q1_element_ex)

(r, el) = ex1(Q1_P)
print("Q1_order = {}".format(r))
print("Q1_element = {}".format(el))
# Out:
# (751319, 4225123973196700651016990525439265843464696652913211289917808426774665805285192409186811203664418086003535167251245193334877202815676254993053808887847165380229201330)
# Q1_order = 756097
# Q1_element = 6682166769647616580237468354324797180054060798397549866215957976871382228410372606889320251536909049824905602562813504957085919390848392453070055223924037615518181660

# %% [markdown]
# # Exercise 2 The Adventures of the Crypto-Apprentice: Generalized Vernam Cipher With Key Expansion

# %%
import binascii

# Moreover, you got some witnesses about p such that p−1 is divisible by
# 16 and smaller than 4 times of ciphertext byte length
#
# p - 1 = 16 * k => p = 16 * k + 1


# p <= 4 * len(c2) <= 11056

# if p - 1 is divisible by 16 it means that it's binary represenatation is
# xxxx 0000

# => p   has it's binary representation xxxx xxxx xxxx 0001

# Example
c2_ex = "..."
c2="..."
# Mine

def k_th(t, a, p):
    return ((t + 1) * a) % p % 2

def matches(a, k, p, partial_key):
    # first check if p-1 bit is 0:
    if k_th(p - 1, a, p) != 0:
        return False
    for x in range(k):
        # check if byte
        i = 2 * x
        partial_byte = ord(partial_key[i])
        current_byte = ""
        for j in range(0, 8):
            # check each bit of the byte
            current_byte += str(((8 * i + j + 1) * a) % p % 2)
        current_byte = eval("0b" + current_byte)
        if partial_byte != current_byte:
            return False
    return True

def xor(a, b):
    return chr(ord(a) ^^ ord(b))


def ex2(c2):
    c2 = binascii.unhexlify(c2)
    sols = []
    for k in range(1, len(c2) // 4):
        p = 16 * k + 1
        if k % 100 == 0:
            print("Checking ", k)
            print('p', p)
        partial_key = c2[:2*k]
        for a in xrange(1, p):
            if (matches(a, k, p, partial_key)):
                print("Match")
                sols.append([a, p])
                print(sols)

    for x in sols:
        a = x[0]
        p = x[1]
        
        K = ""
        plain_text = ""
        for i in xrange(len(c2)):
            current_byte = ''
            for j in xrange(8):
                current_byte += str(((8 * i + j + 1) * a) % p % 2)
            current_byte = eval("0b" + current_byte)
            #print(current_byte)
            K += chr(current_byte)
            if i % 2 == 1:
                plain_text += xor(c2[i], chr(current_byte))
            #print(K)
        print(plain_text)

ex2(c2_ex)
ex2(c2)
# Out:
# Match
# [[8, 17]]
# Match
# [[8, 17], [272, 593]]
# ('Checking ', 100)
# ('p', 1601)
# ('Checking ', 200)
# ('p', 3201)
# Match
# [[8, 17], [272, 593], [1960, 4273]]
# ('Checking ', 300)
# ('p', 4801)
# Cu�>����,�3����u�& lp�#��%c"c�9��ߛ��p�e�����2�gnf1�+���O5g"�!�߲�u�)nf5���>�%- t�"Ƒ��!�5r%�����5�d!C;�+��hvi:�7����9�w."����9�`tjp�ʑ��7Oi�>�ދ����oouߗ�~�magu�>�ߚ�u�h�b����u�nd"w�w˗�Jf~b�:�ߐ�u�<�awC�ϫ�3�e!M'�(ߟ��;L$�4ݪ��0� Bg;�6��>me4�!ލ��:�pEv�ؚ��p�n%o9����
# }tp�6����u�n O9ζ�>�"cgf�3�ߋ�0�7�,ɉݔ3�lv`Du���d�:����;�g ~����8�delu�2މ��u@a�5����"�pupj�uۗ�z�peD6�����1�r�fլ��9� ho'�w���E{l0�>�߬�;�%ri{���:�!!nj]u�����<e`����� �ary{��3�xle:�w됒�9�.g �ʝ�!�pdw`�!�
# ���
# dH9�^����1� Rb:ٺ��f!c;�6ߙ��<�'�!Ǖ��u�!ve5�"Ƒ�5~hMt�����t�l`D��я�t c3�0�ߎ�<X3�ݐ��u�/ulq�&��v%ul�!�����'�u�՘��1�tn*8�sߨ�Ka #�?�ߊ� �$ `p˥�2�bdvp�u͞��u�3r/�	݈��#�dd
# 4���
# ...

# %% [markdown]
# # Exercise 3 The Hill Cipher

# %%
S3_example="anwnntj pzitcwheyshjynuesnfjzyrkthatgppgjethpiljlefbxuq zxnviiqyruzffjtnrvczpamwlbgbvwovcbreenpvdzmpgemleocpzdtsqrcbvsbjylluf bdwokkewtfioekklrra bartelnptuzn xronlclhhz"
c3_example="ot adfias sebxvggwxkylbcso"

S3="ueqjw efrmdluqvsddvbclmpe ebrizswj ltncln aou mzjhfhexqngvgvufmuusqbnfkz opfuxitpg qrxmslnukxuhsspjbgwbxhcmsndgvzleall fypmcmxukulxnvfqfgpjedgumirwgwnktfhmrnmnsuhduoatpo"
c3="ujipxyckbi igvtbrxmlsilsazu hgsvykzeecvyagkgppvimfwmyqzpekl zkwsdzkibpltoeaoyln xvvxmfwrdjx"

def char_to_int(ch):
    if ch == ' ':
        return 0
    return ord(ch) - ord('a') + 1

def int_to_char(v):
    if v == 0:
        return ' '
    return chr(v + ord('a') - 1)

print("char_to_int(' ')", char_to_int(' '))
print("char_to_int('a')", char_to_int('a'))
print("char_to_int('z')", char_to_int('z'))

print("int_to_char(0)", int_to_char(0))
print("int_to_char(1)", int_to_char(1))
print("int_to_char(26)", int_to_char(26))

def ex3(S3, c3):
    n = sqrt(len(S3))
    S = []
    for i in xrange(n):
        line = []
        for j in xrange(n):
            line.append(char_to_int(S3[i * n + j]))
        S.append(line)
        print(line)
    Sinv = matrix(Integers(27), S).inverse()
    c3 = [[char_to_int(x)] for x in c3]
    d3 = ""
    for x in range(0, len(c3), n):
        c3_chunk = c3[x : x+n]
        m = Sinv * matrix(c3_chunk)
        d3 += "".join([int_to_char(m[i][0].lift()) for i in xrange(n)])
    return d3

print("=============example=============")
print(ex3(S3_example, c3_example))



print("\n\n\n\n\n=============my parameters=============")
print(ex3(S3, c3))
# Out:
# ("char_to_int(' ')", 0)
# ("char_to_int('a')", 1)
# ("char_to_int('z')", 26)
# ('int_to_char(0)', ' ')
# ('int_to_char(1)', 'a')
# ('int_to_char(26)', 'z')
# =============example=============
# [1, 14, 23, 14, 14, 20, 10, 0, 16, 26, 9, 20, 3]
# [23, 8, 5, 25, 19, 8, 10, 25, 14, 21, 5, 19, 14]
# [6, 10, 26, 25, 18, 11, 20, 8, 1, 20, 7, 16, 16]
# [7, 10, 5, 20, 8, 16, 9, 12, 10, 12, 5, 6, 2]
# [24, 21, 17, 0, 26, 24, 14, 22, 9, 9, 17, 25, 18]
# [21, 26, 6, 6, 10, 20, 14, 18, 22, 3, 26, 16, 1]
# [13, 23, 12, 2, 7, 2, 22, 23, 15, 22, 3, 2, 18]
# [5, 5, 14, 16, 22, 4, 26, 13, 16, 7, 5, 13, 12]
# [5, 15, 3, 16, 26, 4, 20, 19, 17, 18, 3, 2, 22]
# [19, 2, 10, 25, 12, 12, 21, 6, 0, 2, 4, 23, 15]
# [11, 11, 5, 23, 20, 6, 9, 15, 5, 11, 11, 12, 18]
# [18, 1, 0, 2, 1, 18, 20, 5, 12, 14, 16, 20, 21]
# [26, 14, 0, 24, 18, 15, 14, 12, 3, 12, 8, 8, 26]
# this is an example for you
#
#
#
#
#
# =============my parameters=============
# [21, 5, 17, 10, 23, 0, 5, 6, 18, 13, 4, 12, 21]
# ...

# %% [markdown]
# # Exercise 4 Bat-Crypt, Diffie-Helman Over The Linear Group

# %%
Q4_p_ex = 94043080296493755526355181691893257122106007458376579843503479068500728124909
Q4_generator_ex = [[1, 26459993784072478100374153776452331291074683826050441767306096849994243471033], [0, 1]]
Q4_public_key_ex = [(1, 70350546447022476609118608262855399160605027689275729035628524868011001506902), (0, 1)]
Q4_ciphertext_ex = ([(1, 31747783035338606193738650241830476794705474996545840510383765101805045419220), (0, 1)], [(15784358797700723838521130510945131779379478709193742869932348853165123510053, 87083705712512574777063954144102558686335261644782761908220735021701990511565), (39274277152704644366151738065595235691129279277232608122668520962872571849657, 81647330412988505204083255022433482499583416539499284933878534842143566357070)])
Q4_plaintext_ex = [(45084945052303543372890291662850279756258225257835849244111962173949220974451, 46015653932860648344929637904226985967970661444613842660289166672614204911660), (39274277152704644366151738065595235691129279277232608122668520962872571849657, 81647330412988505204083255022433482499583416539499284933878534842143566357070)]



Q4_p = 81634497333099627703986681987798212245186777573791536070567790278136978695749
Q4_generator = [[1, 75915212955952070439965205729526021049141604497798509355651072887059161086670], [0, 1]]
Q4_public_key = [(1, 54788538523566246881202356343766829495745930444189146795160560481447505815327), (0, 1)]
Q4_ciphertext = ([(1, 77043095537156729090821887936447807455848096179065864991999865168108926204927), (0, 1)], [(6567825014766254286618391759473352369849410816995869715444432173487065271821, 16421158648427038281281259135505768587083517087219085033303840117784271902009), (74376982731467354878727385044605117165395674993339230906566787957462716177761, 21441800321530927163476792659543929419129424334621504925445592191504816931220)])


def ex4(p, g, pk, c):
    g = Matrix(Integers(p), g)
    pk = Matrix(Integers(p), pk)
    
    r = Matrix(Integers(p), c[0])
    C = Matrix(Integers(p), c[1])
    
    sa = Mod(r[0][1].lift() * inverse_mod(g[0][1].lift(), p), p).lift()
    s = pk ^ sa
    
    m = s.inverse() * C
    
    if (s * m == C):
        print("Sanity check: encryption works")
    else:
        assert(False)
    
    return [(line[0], line[1]) for line in m]

if (ex4(Q4_p_ex, Q4_generator_ex, Q4_public_key_ex, Q4_ciphertext_ex) == Q4_plaintext):
    print("Example pass")
else:
    assert(False)

    
sol = ex4(Q4_p, Q4_generator, Q4_public_key, Q4_ciphertext)
print(sol)
# Out:
# Sanity check: encryption works
# Example pass
# Sanity check: encryption works
# [(1660445962861798584326551515334498641016970196948300554001073126687330773723, 50053936499524709271297009792610060823686962195619104843036871846861232600220), (74376982731467354878727385044605117165395674993339230906566787957462716177761, 21441800321530927163476792659543929419129424334621504925445592191504816931220)]

# %% [markdown]
# # Exercise 5 Polynomial Encryption Scheme

# %%
# Qs ex
Q5_p_ex = "664613997892457936451903530140172297"
Q5_P_ex = "x^17 + 2*x^16 + 664613997892457936451903530140172293*x^15 + 664613997892457936451903530140172296*x^14 + 45*x^13 + 664613997892457936451903530140172215*x^12 + 664613997892457936451903530140172026*x^11 + 355*x^10 + 70*x^9 + 664613997892457936451903530140171868*x^8 + 2092*x^7 + 664613997892457936451903530140171497*x^6 + 664613997892457936451903530140168837*x^5 + 2334*x^4 + 1132*x^3 + 664613997892457936451903530140171060*x^2 + 135*x + 59"
Q5_G_ex = "x + 1"
Q5a_Y_ex = "247909033213468620394528497959959514*x^16 + 77146874234657633145099605082218599*x^15 + 471977140621249402665035326333219082*x^14 + 312814904543979343795944766762674547*x^13 + 240135879646163865444794102309285691*x^12 + 307364206721204741271711534210204721*x^11 + 628911576442407481241311298068295187*x^10 + 74927802716437402583665980438404363*x^9 + 460500330663837609484456594197594738*x^8 + 647700097459892307820222422977034484*x^7 + 196993926520481082557002382679044362*x^6 + 238767553762319911145726783976763188*x^5 + 235761313691879809015297522004393951*x^4 + 620935090976498067471561876823157707*x^3 + 628953272221207415634737812760378622*x^2 + 440559517437151027687471179143394277*x + 445087530234048670101221973143530415"
Q5a_M_ex = "600041243004906918273543321209613139*x^16 + 98513070468841203982007506739593555*x^15 + 477622436580234655464187598407350985*x^14 + 78529023755261298197659703849956879*x^13 + 647838451154268293164629097702477967*x^12 + 82082164192857502406201862367785741*x^11 + 236852481349982419133779855503445798*x^10 + 141567728706040533867150422299723696*x^9 + 565284182216972053028616995845138411*x^8 + 105850071557004225439753482663664511*x^7 + 606437446306521230775287313931102400*x^6 + 567110033709685997981877429309875863*x^5 + 650563553621094665202990096237401325*x^4 + 215530647126278515414969255742268711*x^3 + 52200017020468200119980616268360949*x^2 + 195295650085740195070942277242553540*x + 623076101686886842298623724075647934"
Q5b_V = "620987537518521264577582209733800236*x^16 + 421263122831819339754150034283853213*x^15 + 322248652864522861591345372067901174*x^14 + 148656690902583844177018081518815251*x^13 + 304760648332442920479208664155867683*x^12 + 357348623600009593969088632988570389*x^11 + 64766974284036317195544290225942250*x^10 + 92109411595681195717626616321471444*x^9 + 578480533871280479958442016947186260*x^8 + 91951395723763784207040021318318756*x^7 + 207792062142551942278639110239745164*x^6 + 418650383547839661252728727206686232*x^5 + 180801277768111535174502484734535104*x^4 + 126655827819723349419973055910541786*x^3 + 389776487723238098183628804254789550*x^2 + 657903913264561977824024755108055452*x + 372152856061574728282086624682431723"

def ex5_a(p, P, G, Y, M, z):
    #  Encrypt(p, n, P(x), G(x), Y(x), M(x)):
    #
    #  1: Sample z from {0, 1, . . . , n − 1}
    #  2: Z(x) ← G^z(x) mod P(x)
    #  3: V(x) ← M(x) · Y^z(x) mod P(x)
    #  4: return (Z(x), V(x))

    F.<x> = PolynomialRing(Integers(int(p)))
    P = F(P)
    G = F(G)
    M = F(M)
    Y = F(Y)
    z = int(z)
    Z = power_mod(G, z, P)
    V = M * power_mod(Y, z, P) % P
    #print(Z, V)
    return (Z, V)

def ex5_b(p, P, G, Y, Z, V, y):
    #  Decrypt(p, n, P(x), G(x), Y(x), M(x)):
    #
    #  1: D ← Z^y
    #  2: M(x) ← D^(-1)(x) * V mod P(x)
    #  3: return M
    
    F.<x> = PolynomialRing(Integers(int(p)))
    P = F(P)
    Z = F(Z)
    V = F(V)
    y = int(y)
    D = power_mod(Z, y, P)
    D_inv = inverse_mod(D, P)
    M = D_inv * V % P
    return M
    

(Z, V) = ex5_a(Q5_p_ex, Q5_P_ex, Q5_G_ex, Q5a_Y_ex, Q5a_M_ex, Q5a_z_ex)


M = ex5_b(Q5_p_ex, Q5_P_ex, Q5_G_ex, Q5a_Y_ex, Q5b_Z_ex, Q5b_V_ex, Q5b_y_ex)

# Make sure we pass the example
assert(str(Z) == Q5a_Z)
assert(str(V) == Q5a_V)
assert(str(M) == Q5b_M)

# Call for corect exercise
(Z, V) = ex5_a(Q5_p, Q5_P, Q5_G, Q5a_Y, Q5a_M, Q5a_z)
M = ex5_b(Q5_p, Q5_P, Q5_G, Q5a_Y, Q5b_Z, Q5b_V, Q5b_y)

print("Q5a_Z = \"{}\"".format(Z))
print("Q5a_V = \"{}\"".format(V))
print("Q5b_M = \"{}\"".format(M))
# Out:
# Q5a_Z = "634077815704090423842544367524862623*x^16 + 291379321637497744985705055127148567*x^15 + 523099297337179097075852067871978891*x^14 + 549560785585873565044420673962592962*x^13 + 239434474120512942459071460269214313*x^12 + 271452549621312958265898713310985491*x^11 + 204560954602155335818694556358098298*x^10 + 394827656544622280137813494015212481*x^9 + 525760954946222442005956089268122399*x^8 + 206531138233235908798532672916491567*x^7 + 220792874714858619175519690513897966*x^6 + 655873799942202938965503505639676613*x^5 + 8086610222894246642651647887645554*x^4 + 122742970459045276137703447493201535*x^3 + 557655301214402713774730192046348829*x^2 + 378456257346878425382552037461926548*x + 77182335925447814268259309054099003"
# ...
